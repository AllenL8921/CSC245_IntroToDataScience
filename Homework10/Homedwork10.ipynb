# %% [markdown]
# Section 4.1 – MATLAB Plot Basics

# %% [markdown]
# Create a basic line plot of the function y = sin(x) over the interval [0, 2*pi]. Label the axes and add a title.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Plot of y = sin(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# Explain the difference between plot(x, y), plot(y), and plot(x1, y1, x2, y2) in MATLAB. Provide examples.

# %%
plt.plot([0, 1, 2], [0, 1, 4])  # standard x vs. y
plt.plot([3, 1, 4, 1, 5])  # x = [0, 1, 2, 3, 4]
x = np.linspace(0, 2 * np.pi, 100)
plt.plot(x, np.sin(x), x, np.cos(x))  # sin and cos on same plot

# %% [markdown]
# Customize line styles, colors, and markers. Plot y = cos(x) with a red dashed line and circle markers.

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.cos(x)

plt.plot(x, y, 'r--o')  # red dashed line with circle markers
plt.xlabel('x')
plt.ylabel('cos(x)')
plt.title('Plot of y = cos(x)')
plt.grid(True)
plt.show()

# %% [markdown]
# Save a figure to a PNG file with 300 dpi using saveas() and print(). Compare both methods.

# %%
plt.plot(x, y, 'r--o')
plt.title('Cosine Plot')
plt.savefig('cos_plot.png', dpi=300)  # High resolution PNG

# %% [markdown]
# Plot multiple lines on the same axes. Add a legend, grid, and adjust axis limits.

# %%
x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, 'b-', label='sin(x)')
plt.plot(x, y2, 'r--', label='cos(x)')
plt.legend()
plt.xlabel('x')
plt.ylabel('Function Value')
plt.title('sin(x) and cos(x)')
plt.grid(True)
plt.xlim(0, 2 * np.pi)
plt.ylim(-1.5, 1.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Section 4.2 – Formatting and Labels

# %% [markdown]
# Use xlabel(), ylabel(), title(), and legend() to label a plot appropriately.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, label='sin(x)')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Sine Function')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Change font size, font name, and color for axis labels and title.

# %%
plt.plot(x, y)
plt.xlabel('X Axis', fontsize=14, fontname='Comic Sans MS', color='blue')
plt.ylabel('Y Axis', fontsize=14, fontname='Arial', color='green')
plt.title('Styled Plot Title', fontsize=16, fontname='Times New Roman', color='purple')
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Comic Sans MS' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Times New Roman' not found.

# %% [markdown]
# Use gca and set() to customize axes properties like limits, ticks, and gridlines.

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# Customize using set()
ax.set_xlim(0, 10)
ax.set_ylim(-1.5, 1.5)
ax.set_xticks(np.arange(0, 11, 2))
ax.set_yticks([-1, 0, 1])
ax.grid(True)

plt.title('Custom Axes Settings')
plt.show()

# %% [markdown]
# Annotate a plot using text() and annotation() for arrows or notes.

# %%
plt.plot(x, y)
plt.title('Annotation Example')

# Add static text
plt.text(3, 0.5, 'Local label', fontsize=12, color='red')

# Add arrow annotation
plt.annotate('Peak', xy=(np.pi/2, 1), xytext=(2, 1.2),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.show()

# %% [markdown]
# Create a figure with subplots and individual titles for each.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))

x = np.linspace(0, 2*np.pi, 100)
axs[0, 0].plot(x, np.sin(x))
axs[0, 0].set_title('sin(x)')

axs[0, 1].plot(x, np.cos(x), 'r')
axs[0, 1].set_title('cos(x)')

axs[1, 0].plot(x, np.tan(x), 'g')
axs[1, 0].set_title('tan(x)')
axs[1, 0].set_ylim(-5, 5)

axs[1, 1].plot(x, np.exp(-x))
axs[1, 1].set_title('exp(-x)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Section 4.3 – Multiple Plots and Subplots

# %% [markdown]
# Use subplot() to create a 2x2 grid of plots for sine, cosine, tangent, and exponential functions.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2 * np.pi, 100)
functions = [np.sin, np.cos, np.tan, lambda x: np.exp(-x)]
titles = ['sin(x)', 'cos(x)', 'tan(x)', 'exp(-x)']

plt.figure(figsize=(10, 8))

for i, func in enumerate(functions, 1):
    plt.subplot(2, 2, i)
    plt.plot(x, func(x))
    plt.title(titles[i-1])
    if titles[i-1] == 'tan(x)':
        plt.ylim(-5, 5)  # limit for tan(x)

plt.tight_layout()
plt.show()

# %% [markdown]
# Compare subplot() vs tiledlayout(). Plot the same functions using both methods.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

funcs = [np.sin, np.cos, np.tan, lambda x: np.exp(-x)]
titles = ['sin(x)', 'cos(x)', 'tan(x)', 'exp(-x)']

for ax, func, title in zip(axs.flat, funcs, titles):
    ax.plot(x, func(x))
    ax.set_title(title)
    if title == 'tan(x)':
        ax.set_ylim(-5, 5)

plt.tight_layout()
plt.show()

# %% [markdown]
# Share axes across subplots and remove redundant tick labels.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for ax, func, title in zip(axs.flat, functions, titles):
    ax.plot(x, func(x))
    ax.set_title(title)
    if title == 'tan(x)':
        ax.set_ylim(-5, 5)

plt.tight_layout()
plt.show()

# %% [markdown]
# Use linkaxes() to synchronize zooming/panning across multiple plots.

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create first subplot
ax1 = plt.subplot(2, 1, 1)   # 2 rows, 1 column, 1st subplot
ax1.plot(x, y1)
ax1.set_title('sin(x)')

# Create second subplot, sharing the x-axis with ax1
ax2 = plt.subplot(2, 1, 2, sharex=ax1)
ax2.plot(x, y2)
ax2.set_title('cos(x)')

# Add axis labels
ax1.set_ylabel('Amplitude')
ax2.set_xlabel('x')
ax2.set_ylabel('Amplitude')

plt.setp(ax1.get_xticklabels(), visible=False)

plt.tight_layout()
plt.show()

# %% [markdown]
# Export the whole multi-panel figure to PDF with appropriate formatting.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

for ax, func, title in zip(axs.flat, functions, titles):
    ax.plot(x, func(x))
    ax.set_title(title)
    if title == 'tan(x)':
        ax.set_ylim(-5, 5)

plt.tight_layout()
fig.savefig("multi_panel_plot.pdf", format='pdf', dpi=300)

# %% [markdown]
# Section 4.4 – Specialized Plot Types

# %% [markdown]
# Create and customize bar plots using bar() and barh().

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['A', 'B', 'C', 'D']
values = [10, 24, 36, 18]

# Vertical bar plot
plt.bar(categories, values, color='skyblue')
plt.title('Vertical Bar Plot')
plt.xlabel('Category')
plt.ylabel('Value')
plt.show()

# Horizontal bar plot
plt.barh(categories, values, color='lightgreen')
plt.title('Horizontal Bar Plot')
plt.xlabel('Value')
plt.ylabel('Category')
plt.show()

# %% [markdown]
# Generate a histogram from random normal data. Adjust bin width and color.

# %%
data = np.random.randn(1000)  # Normal distribution

plt.hist(data, bins=30, color='salmon', edgecolor='black')  # Adjust bin width with bins
plt.title('Histogram of Normally Distributed Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Use scatter() for plotting noisy (x, y) data. Change marker size based on third variable.

# %%
x = np.random.rand(100)
y = np.random.rand(100)
sizes = 100 * np.random.rand(100)  # Third variable for marker size

plt.scatter(x, y, s=sizes, alpha=0.6, c='purple')
plt.title('Scatter Plot with Variable Marker Sizes')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# Generate a pie chart from categorical data and add percentage labels.

# %%
labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [35, 25, 20, 20]
colors = ['gold', 'skyblue', 'lightcoral', 'lightgreen']

plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Programming Language Popularity')
plt.axis('equal')  # Equal aspect ratio ensures the pie is circular.
plt.show()

# %% [markdown]
# Create an area plot and stacked area plot. Describe use cases for each.

# %%
x = np.arange(1, 6)
y1 = np.array([1, 2, 3, 4, 5])
y2 = np.array([2, 1, 4, 2, 1])

# Simple area plot
plt.fill_between(x, y1, color='lightblue', alpha=0.7)
plt.title('Simple Area Plot')
plt.show()

# Stacked area plot
y = np.vstack([y1, y2])
plt.stackplot(x, y, labels=['y1', 'y2'], colors=['skyblue', 'lightgreen'])
plt.title('Stacked Area Plot')
plt.legend()
plt.show()

# %% [markdown]
# Section 4.5 – 3D Plotting

# %% [markdown]
# Plot a 3D surface using surf() for z = sin(x) * cos(y).
#
# Add colorbars and shading to improve visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Needed for 3D plots

x = np.linspace(-3, 3, 100)
y = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')
plt.title('3D Surface: sin(x) * cos(y)')
plt.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %% [markdown]
# Use meshgrid() and mesh() to plot wireframe surfaces.

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(X, Y, Z, color='gray', linewidth=0.5)
plt.title('3D Wireframe Plot')
plt.show()

# %% [markdown]
# Animate rotation of a 3D plot using view() in a loop.

# %%
import matplotlib.animation as animation

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='plasma')

def rotate(angle):
    ax.view_init(elev=30, azim=angle)

ani = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 360, 2), interval=100)
plt.show()

# %% [markdown]
# Use contour3() to add contours to a 3D surface.

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='inferno')
ax.set_title('3D Contour Plot')
plt.show()

# %% [markdown]
# Section 4.6 – Interactive and Advanced Plotting

# %% [markdown]
# Use ginput() to capture mouse clicks and annotate those points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a simple plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Click on the plot to capture points")

# Capture 3 points
points = plt.ginput(n=3, timeout=0)

# Annotate the clicked points
for point in points:
    plt.annotate(f'({point[0]:.2f}, {point[1]:.2f})', 
                 (point[0], point[1]), textcoords="offset points", 
                 xytext=(0,10), ha='center', color='red')

plt.show()
# Out:
# /tmp/ipykernel_26270/1000882170.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   points = plt.ginput(n=3, timeout=0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 12
#       9 plt.title("Click on the plot to capture points")
#      11 # Capture 3 points
# ---> 12 points = plt.ginput(n=3, timeout=0)
#      14 # Annotate the clicked points
#      15 for point in points:
#
# File ~/CSC245_IntroToDataScience/myenv/lib/python3.12/site-packages/matplotlib/pyplot.py:2793, in ginput(n, timeout, show_clicks, mouse_add, mouse_pop, mouse_stop)
#    2784 @_copy_docstring_and_deprecators(Figure.ginput)
#    2785 def ginput(
#    2786     n: int = 1,
#    (...)
#    2791     mouse_stop: MouseButton = MouseButton.MIDDLE,
#    2792 ) -> list[tuple[int, int]]:
# -> 2793     return gcf().ginput(
#    2794         n=n,
# ...

# %% [markdown]
# Add interactivity using uicontrol() elements like sliders.

# %%
from matplotlib.widgets import Slider
import numpy as np
import matplotlib.pyplot as plt

# Initial plot setup
x = np.linspace(0, 10, 100)
y = np.sin(x)
fig, ax = plt.subplots()
line, = ax.plot(x, y)

# Slider axis
ax_slider = plt.axes([0.2, 0.01, 0.65, 0.03], facecolor='lightgoldenrodyellow')
slider = Slider(ax_slider, 'Frequency', 0.1, 10.0, valinit=1)

# Update function for slider
def update(val):
    freq = slider.val
    line.set_ydata(np.sin(freq * x))
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()

# %% [markdown]
# Use datacursormode to explore points interactively.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.linspace(0, 10, 100)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)

# Enable data cursor mode
plt.gca().set_title("Click on the points to explore data")

# Enable data cursor mode
plt.datacursormode(True)

plt.show()

# %% [markdown]
# Create an animated line plot using animatedline().

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_xlim(0, 2 * np.pi)
ax.set_ylim(-1.1, 1.1)

# Initialization function
def init():
    line.set_data([], [])
    return line,

# Update function for animation
def update(frame):
    line.set_data(x[:frame], y[:frame])
    return line,

ani = FuncAnimation(fig, update, frames=range(1, len(x)+1), init_func=init, blit=True, interval=50)

plt.show()

# %% [markdown]
# Combine plot3() and comet3() to show 3D trajectories over time.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation

# Generate 3D data (spiral trajectory)
theta = np.linspace(0, 2*np.pi, 100)
z = np.linspace(0, 10, 100)
x = np.sin(theta) * z
y = np.cos(theta) * z

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
ax.set_zlim([0, 10])

# Initial plot setup
line, = ax.plot([], [], [], marker='o', markersize=5)

# Initialization function
def init():
    line.set_data([], [])
    line.set_3d_properties([], [])
    return line,

# Update function for animation
def update(frame):
    line.set_data(x[:frame], y[:frame])
    line.set_3d_properties(z[:frame])
    return line,

ani = FuncAnimation(fig, update, frames=len(x), init_func=init, blit=True, interval=100)

plt.show()
